# %% [markdown]
# ## Library instalation

# %%
# !pip install torch torchvision
# !pip install opencv-contrib-python
# !pip install scikit-learn
# !pip install kaggle

# %% [markdown]
# ## Downloading the data

# %%
# !pwd
# Out:
# /dockervolume

# %%
# Move kaggle.json to the required directory
# !mkdir -p ~/.kaggle
# !cp ./kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json

# %%
# !kaggle datasets download -d paultimothymooney/chest-xray-pneumonia
# Out:
# ...
# 100%|█████████████████████████████████████▉| 2.29G/2.29G [03:27<00:00, 11.8MB/s]
# 100%|██████████████████████████████████████| 2.29G/2.29G [03:27<00:00, 11.8MB/s]

# %%
# !unzip chest-xray-pneumonia.zip
# Out:
# Archive:  chest-xray-pneumonia.zip
#   inflating: chest_xray/__MACOSX/._chest_xray
#   inflating: chest_xray/__MACOSX/chest_xray/._.DS_Store
#   inflating: chest_xray/__MACOSX/chest_xray/._test
#   inflating: chest_xray/__MACOSX/chest_xray/._train
#   inflating: chest_xray/__MACOSX/chest_xray/test/._.DS_Store
#   inflating: chest_xray/__MACOSX/chest_xray/test/._NORMAL
#   inflating: chest_xray/__MACOSX/chest_xray/test/._PNEUMONIA
#   inflating: chest_xray/__MACOSX/chest_xray/test/NORMAL/._IM-0001-0001.jpeg
#   inflating: chest_xray/__MACOSX/chest_xray/test/NORMAL/._IM-0003-0001.jpeg
#   inflating: chest_xray/__MACOSX/chest_xray/test/NORMAL/._IM-0005-0001.jpeg
#   inflating: chest_xray/__MACOSX/chest_xray/test/NORMAL/._IM-0006-0001.jpeg
#   inflating: chest_xray/__MACOSX/chest_xray/test/NORMAL/._IM-0007-0001.jpeg
#   inflating: chest_xray/__MACOSX/chest_xray/test/NORMAL/._IM-0009-0001.jpeg
#   inflating: chest_xray/__MACOSX/chest_xray/test/NORMAL/._IM-0010-0001.jpeg
# ...

# %% [markdown]
# ## Loading the data, histogram equalization, resize and normailzation

# %%
import os
import torch
from torchvision import datasets, transforms
from torch.utils.data import DataLoader, Dataset
import matplotlib.pyplot as plt
import numpy as np
from PIL import Image
import cv2

class ChestXRayDataset(Dataset):
    def __init__(self, root_dir, transform=None):
        self.root_dir = root_dir
        self.transform = transform
        self.classes = ['NORMAL', 'PNEUMONIA']
        self.image_paths = []
        self.labels = []

        for idx, class_name in enumerate(self.classes):
            class_path = os.path.join(self.root_dir, class_name)
            for image_name in os.listdir(class_path):
                self.image_paths.append(os.path.join(class_path, image_name))
                self.labels.append(idx)

    def __len__(self):
        return len(self.image_paths)

    def __getitem__(self, idx):
        img_path = self.image_paths[idx]
        image = datasets.folder.default_loader(img_path)
        label = self.labels[idx]

        if self.transform:
            image = self.transform(image)

        return image, label

def histogram_equalization(img):

    img_np = np.array(img)
    if len(img_np.shape) == 3:  # Check if the image is color (3 channels)
        img_np = cv2.cvtColor(img_np, cv2.COLOR_RGB2GRAY)
    img_eq = cv2.equalizeHist(img_np)

    img = Image.fromarray(img_eq)

    return img

hist_eq_transform = transforms.Lambda(histogram_equalization)

transform_with_hist_eq = transforms.Compose([
    transforms.Resize((224, 224)),
    hist_eq_transform,  # Apply histogram equalization
    transforms.ToTensor(),
    transforms.Normalize(mean=[0], std=[1])
])


train_dataset_with_hist_eq = ChestXRayDataset(root_dir='./chest_xray/train', transform=transform_with_hist_eq)
test_dataset_with_hist_eq = ChestXRayDataset(root_dir='./chest_xray/test', transform=transform_with_hist_eq)
val_dataset_with_hist_eq = ChestXRayDataset(root_dir='./chest_xray/val', transform=transform_with_hist_eq)



train_dataset = ChestXRayDataset(root_dir='./chest_xray/train')
test_dataset = ChestXRayDataset(root_dir='./chest_xray/test')
val_dataset = ChestXRayDataset(root_dir='./chest_xray/val')

# %% [markdown]
# ## Visualization

# %%
import random
rand_ind = random.randint(0,len(train_dataset))
img, label = train_dataset[rand_ind]

classes = ['Normal','Pneumonia']
plt.figure(figsize = (5,5))
plt.imshow(train_dataset[rand_ind][0], cmap='gray')
plt.title(classes[train_dataset[rand_ind][1]])
# Out:
# Text(0.5, 1.0, 'Pneumonia')

# %%
rand_ind = random.randint(0,len(train_dataset_with_hist_eq))
img, label = train_dataset_with_hist_eq[rand_ind]

classes = ['Normal','Pneumonia']
plt.figure(figsize = (5,5))
plt.imshow(train_dataset_with_hist_eq[rand_ind][0].reshape((224,224)), cmap='gray')
plt.title(classes[train_dataset_with_hist_eq[rand_ind][1]])
# Convert PIL Image to NumPy array
image_array = np.array(img)

# Display the minimum and maximum pixel intensity values (magnitudes)
print("Minimum pixel intensity:", np.min(image_array))
print("Maximum pixel intensity:", np.max(image_array))
# Out:
# Minimum pixel intensity: 0.0
# Maximum pixel intensity: 1.0

# %% [markdown]
# ## Check class imbalance

# %%
import matplotlib.pyplot as plt

def plot_label_distribution(dataset, title):
    label_counts = {'Normal': 0, 'Pneumonia': 0}

    # Count occurrences of each label in the dataset
    for _, label in dataset:
        if label == 0:
            label_counts['Normal'] += 1
        else:
            label_counts['Pneumonia'] += 1

    # Plotting
    labels = list(label_counts.keys())
    counts = list(label_counts.values())

    plt.figure(figsize=(8, 6))
    plt.bar(labels, counts, color=['blue', 'red'])
    plt.xlabel('Labels')
    plt.ylabel('Number of Samples')
    plt.title(title)
    for i, count in enumerate(counts):
        plt.text(i, count, str(count), ha='center', va='bottom', fontsize=12)
    plt.show()

plot_label_distribution(train_dataset_with_hist_eq, title='Train Dataset Labels')
plot_label_distribution(test_dataset_with_hist_eq, title='Test Dataset Labels')
plot_label_distribution(val_dataset_with_hist_eq, title='Validation Dataset Labels')

# %%
len(train_dataset)
# Out:
# 5216

# %% [markdown]
# ## Data Augmentation

# %% [markdown]
# To make up for class imbalance

# %%
# Define transformations for data augmentation
transform_augmented = transforms.Compose([
    transforms.RandomApply([
            transforms.RandomOrder([
                transforms.RandomResizedCrop(224, scale=(0.8, 1.0)),  # Randomly crop the image and resize it to 224x224
                transforms.RandomVerticalFlip(),  # Randomly flip the image horizontally
                transforms.RandomHorizontalFlip(),  # Randomly flip the image horizontally
                transforms.GaussianBlur(kernel_size=(3, 3), sigma=(0.1, 0.3)),
                transforms.RandomAffine(degrees = (0, 10),translate=(0.1, 0.3))
            ])],
            p=0.3
        ),
    # Assuming you have a variable named 'hist_eq_transform' for histogram equalization
    transforms.Resize((224,224)),
    hist_eq_transform,  # Apply histogram equalization
    transforms.ToTensor(),  # Convert PIL Image to PyTorch tensor
    transforms.Normalize(mean=[0], std=[1])
])


# Apply transformations to the train_dataset
train_dataset_aug = ChestXRayDataset(root_dir='./chest_xray/train', transform=transform_augmented)
len(train_dataset_aug)
# Out:
# 5216

# %% [markdown]
# Check to make sure the Xray images still look like Xray images after augmentation

# %%
rand_ind = random.randint(0,len(train_dataset_aug))
img, label = train_dataset_aug[rand_ind]

classes = ['Normal','Pneumonia']
plt.figure(figsize = (5,5))
plt.imshow(train_dataset_aug[rand_ind][0].reshape((224,224)), cmap='gray')
plt.title(classes[train_dataset_aug[rand_ind][1]])
# Convert PIL Image to NumPy array
image_array = np.array(img)

# Display the minimum and maximum pixel intensity values (magnitudes)
print("Minimum pixel intensity:", np.min(image_array))
print("Maximum pixel intensity:", np.max(image_array))
# Out:
# Minimum pixel intensity: 0.0
# Maximum pixel intensity: 1.0

# %%
increased_dataset = []
all_labels = []
for _ in range(3):
  train_dataset_aug = ChestXRayDataset(root_dir='./chest_xray/train', transform=transform_augmented)
  increased_dataset = torch.utils.data.ConcatDataset([train_dataset_aug,increased_dataset])
  all_labels.extend(train_dataset_aug.labels)

# %%
len(increased_dataset)
# Out:
# 15648

# %%
# train_loader = DataLoader(increased_dataset, batch_size=32, shuffle=True)
# test_loader = DataLoader(test_dataset_with_hist_eq, batch_size=32, shuffle=False)
# val_loader = DataLoader(val_dataset_with_hist_eq, batch_size=32, shuffle=False)

# %% [markdown]
# ## Part1: Unsupervised

# %% [markdown]
# Use PCA to reduce dimensions so KMeans++ is done easier.
# KMeans++ is chosen for it's simplicity, computational efficiency and speed. This makes it suitable for data with a large number of samples and features.
# Also KMeans++ is less sensitive to initialization compared to KMeans.

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans


# Convert dataset into a format suitable for feature extraction
# data = [np.array(img).flatten() for img, label in increased_dataset]
data = [np.array(img).flatten() for img, label in test_dataset_with_hist_eq]
data = np.array(data)

# Standardize the data
scaler = StandardScaler()
scaled_data = scaler.fit_transform(data)

# Apply PCA
pca = PCA() 
principal_components = pca.fit_transform(scaled_data)

# %%
# Calculate cumulative explained variance ratio
cumulative_variance = np.cumsum(pca.explained_variance_ratio_)

# Find the number of components that explain 90% variance
n_components_90 = np.argmax(cumulative_variance >= 0.90) + 1

n_components_95 = np.argmax(cumulative_variance >= 0.95) + 1

# Plotting
plt.figure(figsize=(10, 6))

# Plot cumulative explained variance
plt.plot(cumulative_variance, marker='o', linestyle='-', label='Cumulative Explained Variance')

# Plot 90% variance line
plt.axhline(y=0.90, color='r', linestyle='--', label='90% Variance')

# Plot 95% variance line
plt.axhline(y=0.95, color='g', linestyle='--', label='95% Variance')

# Highlight the point of 90 variance
plt.scatter(n_components_90, 0.90, color='red')
plt.text(n_components_90, 0.90, f'  ({n_components_90}, 0.90)', fontsize=12, verticalalignment='bottom')

plt.scatter(n_components_95, 0.95, color='red')
plt.text(n_components_95, 0.95, f'  ({n_components_95}, 0.95)', fontsize=12, verticalalignment='bottom')

plt.xlabel('Number of Components')
plt.ylabel('Cumulative Explained Variance')
plt.title('Cumulative Explained Variance vs. Number of Components')
plt.legend()
plt.grid(True)
plt.show()

print(f"Number of components explaining 90% variance: {n_components_90}")
print(f"Number of components explaining 95% variance: {n_components_95}")
# Out:
# Number of components explaining 90% variance: 183
# Number of components explaining 95% variance: 299

# %%
pca = PCA(n_components=n_components_90) 
data_pca = pca.fit_transform(scaled_data)


print("Shape after PCA:", data_pca.shape)
# Out:
# Shape after PCA: (624, 183)

# %%
# data_pca.shape

# %%
num_clusters = 2
kmeans = KMeans(n_clusters=num_clusters, init='k-means++', random_state=42)
labels = kmeans.fit_predict(data_pca)
print(labels.size)
# Out:
# 624

# %%
true_test_labels = [label for _, label in test_dataset_with_hist_eq]


test_accuracy = accuracy_score(true_test_labels, labels)  # Adjust based on your scenario

print(f"Test Accuracy: {test_accuracy * 100:.2f}%")
# Out:
# Test Accuracy: 27.72%

# %% [markdown]
# Low Test Accuracy

# %% [markdown]
# ## Unsupervised (2) GMM

# %%
from sklearn.mixture import GaussianMixture

n_components = 2  

gmm = GaussianMixture(n_components=n_components, random_state=42)
gmm.fit(data_pca)
# Out:
# GaussianMixture(n_components=2, random_state=42)

# %%
predicted_clusters = gmm.predict(data_pca)

true_labels = [label for _, label in test_dataset_with_hist_eq]

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# Compute metrics
accuracy = accuracy_score(true_labels, predicted_clusters)
precision = precision_score(true_labels, predicted_clusters)
recall = recall_score(true_labels, predicted_clusters)
f1 = f1_score(true_labels, predicted_clusters)

print(f"Accuracy: {accuracy:.4f}")
print(f"Precision: {precision:.4f}")
print(f"Recall: {recall:.4f}")
print(f"F1-score: {f1:.4f}")
# Out:
# Accuracy: 0.7179
# Precision: 0.9385
# Recall: 0.5872
# F1-score: 0.7224

# %% [markdown]
# Description of metrics is detailed later on this document.

# %% [markdown]
# ## Part2: Supervised

# %% [markdown]
# CNNs have many desirable features when it comes to image classification. They capture higher-level features such as shapes and object, parameter sharing between convolutional layers reduces the number of weights that need to be trained helping the generalization of the network and they're translation invariant.

# %%
import torch.nn as nn
import torch.nn.functional as F

class SimpleCNN(nn.Module):
    def __init__(self):
        super(SimpleCNN, self).__init__()

        # Convolutional layers with batch normalization
        self.conv1 = nn.Conv2d(in_channels=1, out_channels=32, kernel_size=3, stride=1, padding=1)
        self.bn1 = nn.BatchNorm2d(32)

        self.conv2 = nn.Conv2d(in_channels=32, out_channels=64, kernel_size=3, stride=1, padding=1)
        self.bn2 = nn.BatchNorm2d(64)

        # Max pooling layer
        self.pool = nn.MaxPool2d(kernel_size=2, stride=2)

        # Fully connected layers
        self.fc1 = nn.Linear(64 * 56 * 56, 128)
        self.fc2 = nn.Linear(128, 2)  # 2 classes: Normal and Pneumonia

    def forward(self, x):
        x = self.pool(F.relu(self.bn1(self.conv1(x))))

        x = self.pool(F.relu(self.bn2(self.conv2(x))))

        x = x.view(-1, 64 * 56 * 56)  

        x = F.relu(self.fc1(x))

        x = self.fc2(x)
        return x

# %%
from sklearn.model_selection import StratifiedKFold


labels_array = np.array([0,1])
labels = [0,1]
k_folds = 5
skf = StratifiedKFold(n_splits=k_folds, shuffle=True, random_state=42)

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")
# Out:
# Using device: cuda

# %%
import torch.optim as optim

model = SimpleCNN()
model.to(device)
epochs = 10
learning_rate = 0.001

criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=learning_rate)
best_val_loss = float('inf')  # Initialize with a very high value
best_model = None

train_losses = []
val_losses = []

print_frequency = 5  # Print every 5 epochs

for fold, (train_index, val_index) in enumerate(skf.split(np.zeros(len(increased_dataset)), all_labels)):
    train_sampler = torch.utils.data.SubsetRandomSampler(train_index)
    val_sampler = torch.utils.data.SubsetRandomSampler(val_index)

    train_loader = DataLoader(increased_dataset, batch_size=32, shuffle=True)
    val_loader = DataLoader(val_dataset_with_hist_eq, batch_size=32, shuffle=False)

    for epoch in range(epochs):
        model.train()
        running_train_loss = 0.0
        for batch_idx, (data, target) in enumerate(train_loader):
            data, target = data.to(device), target.to(device)
            optimizer.zero_grad()
            output = model(data)
            loss = criterion(output, target)
            loss.backward()
            optimizer.step()

            running_train_loss += loss.item()

        # Validation loop
        if (epoch + 1) % print_frequency == 0 or epoch == epochs - 1:
            model.eval()
            val_loss = 0
            correct = 0
            total = 0
            with torch.no_grad():
                for data, target in val_loader:
                    data, target = data.to(device), target.to(device)
                    output = model(data)
                    loss = criterion(output, target)
                    val_loss += loss.item()

                    _, predicted = output.max(1)
                    total += target.size(0)
                    correct += predicted.eq(target).sum().item()

            avg_val_loss = val_loss / len(val_loader)
            accuracy = 100. * correct / total
            print(f'Fold: {fold + 1}, Epoch: {epoch + 1}, Validation Loss: {avg_val_loss:.4f}, Accuracy: {accuracy:.2f}%')

            train_losses.append(running_train_loss / len(train_loader))
            val_losses.append(avg_val_loss)

            # Update the plot
            plt.clf()
            plt.figure(figsize=(5, 5))
            plt.plot(train_losses, label='Training Loss', color='blue')
            plt.plot(val_losses, label='Validation Loss', color='red')
            plt.title(f'Fold: {fold + 1}, Epoch: {epoch + 1}')
            plt.xlabel('Epochs')
            plt.ylabel('Loss')
            plt.legend()
            plt.show()

            if avg_val_loss < best_val_loss:
                best_val_loss = avg_val_loss
                best_model = model.state_dict()
# Out:
# Fold: 1, Epoch: 5, Validation Loss: 0.3286, Accuracy: 87.50%
# Fold: 1, Epoch: 10, Validation Loss: 0.1567, Accuracy: 93.75%
# Fold: 2, Epoch: 5, Validation Loss: 0.9880, Accuracy: 75.00%
# Fold: 2, Epoch: 10, Validation Loss: 0.6120, Accuracy: 62.50%
# Fold: 3, Epoch: 5, Validation Loss: 0.1814, Accuracy: 93.75%
# Fold: 3, Epoch: 10, Validation Loss: 0.6740, Accuracy: 81.25%
# Fold: 4, Epoch: 5, Validation Loss: 0.1762, Accuracy: 93.75%
# Fold: 4, Epoch: 10, Validation Loss: 0.0174, Accuracy: 100.00%
# Fold: 5, Epoch: 5, Validation Loss: 3.2292, Accuracy: 62.50%
# Fold: 5, Epoch: 10, Validation Loss: 0.4257, Accuracy: 81.25%

# %% [markdown]
# Precision is essential when the cost of false positives is high. A high precision indicates that the model correctly identifies the positive samples with minimal false positives.
#
# Recall is crucial when the cost of false negatives is high. In scenarios like disease detection, missing a positive case can have severe consequences.
#
# F1-score is useful when you need to consider both precision and recall. A higher F1-score indicates a better balance between precision and recall, which is beneficial when we have class imbalance.
#
# Accuracy provides a general measure of the model's correctness, but in datasets where one class significantly outnumbers the other(s), accuracy can be misleading. A model might achieve high accuracy by simply predicting the majority class for all instances, ignoring the minority class.

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# Ensure model is in evaluation mode
model = SimpleCNN().to(device)
model.load_state_dict(best_model)
model.eval()

true_labels = []
predicted_labels = []

with torch.no_grad():
    for data, target in test_loader:
        data, target = data.to(device), target.to(device)

        # Forward pass
        output = model(data)

        # Convert output probabilities to predicted class
        _, predicted = torch.max(output, 1)

        # Store true and predicted labels for later calculation
        true_labels.extend(target.cpu().numpy())
        predicted_labels.extend(predicted.cpu().numpy())

# Convert lists to numpy arrays for metrics calculation
true_labels = np.array(true_labels)
predicted_labels = np.array(predicted_labels)

# Compute metrics
accuracy = accuracy_score(true_labels, predicted_labels)
precision = precision_score(true_labels, predicted_labels)
recall = recall_score(true_labels, predicted_labels)
f1 = f1_score(true_labels, predicted_labels)

print(f"Accuracy: {accuracy:.4f}")
print(f"Precision: {precision:.4f}")
print(f"Recall: {recall:.4f}")
print(f"F1-score: {f1:.4f}")
# Out:
# Accuracy: 0.7276
# Precision: 0.7007
# Recall: 0.9846
# F1-score: 0.8188

# %%
from sklearn.metrics import confusion_matrix

# Compute confusion matrix
cm = confusion_matrix(true_labels, predicted_labels)

# Create a figure and a subplot
plt.figure(figsize=(8, 6))
plt.imshow(cm, interpolation='nearest', cmap=plt.cm.Blues)
plt.title('Confusion Matrix')
plt.colorbar()

# Setting the ticks for the classes
classes = [0, 1]
tick_marks = np.arange(len(classes))
plt.xticks(tick_marks, classes)
plt.yticks(tick_marks, classes)

# Adding annotations
thresh = cm.max() / 2.
for i in range(cm.shape[0]):
    for j in range(cm.shape[1]):
        plt.text(j, i, format(cm[i, j], 'd'),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

# Labeling axes
plt.xlabel('Predicted labels')
plt.ylabel('True labels')
plt.tight_layout()
plt.show()

# %%
# Compute ROC curve and AUC
from sklearn.metrics import roc_curve, auc
fpr, tpr, _ = roc_curve(true_labels, predicted_labels)
roc_auc = auc(fpr, tpr)

# Plot ROC curve
plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, color='darkorange', lw=2, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc="lower right")
plt.grid(True)
plt.show()

# %% [markdown]
# ## Supervised (2) using mobilenet-v3-small

# %% [markdown]
# Mobilenet is used for finetuning, because it's a lightweight pretrained CNN.

# %%
import torchvision.models as models

# Load pre-trained MobileNetV3 model
model = models.mobilenet_v3_small(pretrained=True)  # You can also use mobilenet_v3_large
# Out:
# /opt/conda/lib/python3.8/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /opt/conda/lib/python3.8/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=MobileNet_V3_Small_Weights.IMAGENET1K_V1`. You can also use `weights=MobileNet_V3_Small_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/mobilenet_v3_small-047dcff4.pth" to /root/.cache/torch/hub/checkpoints/mobilenet_v3_small-047dcff4.pth
# 100%|██████████| 9.83M/9.83M [00:00<00:00, 11.8MB/s]

# %%
#Modify Last layer

# %%
num_classes = len(train_dataset.classes) 

# Check the structure of the classifier to understand its components
print(model.classifier)

in_features = model.classifier[-1].in_features  # Accessing the last linear layer in the classifier
model.features[0][0] = nn.Conv2d(1, 16, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False) #modify first layer to get gray images
model.classifier[-1] = nn.Linear(in_features, num_classes)  # Modify the last layer to fit the number of classes
model = model.to(device)  # Move model to GPU if available
# Out:
# Sequential(
#   (0): Linear(in_features=576, out_features=1024, bias=True)
#   (1): Hardswish()
#   (2): Dropout(p=0.2, inplace=True)
#   (3): Linear(in_features=1024, out_features=2, bias=True)
# )

# %%
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)

# %%
epochs = 10  
best_val_loss = float('inf')

for epoch in range(epochs):
    model.train()
    running_loss = 0.0
    for inputs, labels in train_loader:
        inputs, labels = inputs.to(device), labels.to(device)
        
        optimizer.zero_grad()
        
        outputs = model(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        
        running_loss += loss.item()

    model.eval()
    with torch.no_grad():
        val_loss = 0.0
        for inputs, labels in val_loader:
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = model(inputs)
            val_loss += criterion(outputs, labels).item()
    
    if val_loss < best_val_loss:
                best_val_loss = avg_val_loss
                best_model = model.state_dict()
    print(f"Epoch {epoch+1}/{epochs}, Training Loss: {running_loss/len(train_loader):.4f}, Validation Loss: {val_loss/len(val_loader):.4f}")

print("Finished Training")
# Out:
# Epoch 1/10, Training Loss: 0.0686, Validation Loss: 0.4649
# Epoch 2/10, Training Loss: 0.0490, Validation Loss: 1.4289
# Epoch 3/10, Training Loss: 0.0487, Validation Loss: 0.0640
# Epoch 4/10, Training Loss: 0.0519, Validation Loss: 0.6106
# Epoch 5/10, Training Loss: 0.0481, Validation Loss: 2.1539
# Epoch 6/10, Training Loss: 0.0483, Validation Loss: 2.5084
# Epoch 7/10, Training Loss: 0.0449, Validation Loss: 0.5971
# Epoch 8/10, Training Loss: 0.0466, Validation Loss: 0.4591
# Epoch 9/10, Training Loss: 0.0454, Validation Loss: 0.2758
# Epoch 10/10, Training Loss: 0.0335, Validation Loss: 0.3286
# Finished Training

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# Ensure model is in evaluation mode
model.load_state_dict(best_model)
model.eval()

true_labels = []
predicted_labels = []

with torch.no_grad():
    for data, target in test_loader:
        data, target = data.to(device), target.to(device)

        # Forward pass
        output = model(data)

        # Convert output probabilities to predicted class
        _, predicted = torch.max(output, 1)

        # Store true and predicted labels for later calculation
        true_labels.extend(target.cpu().numpy())
        predicted_labels.extend(predicted.cpu().numpy())

# Convert lists to numpy arrays for metrics calculation
true_labels = np.array(true_labels)
predicted_labels = np.array(predicted_labels)

# Compute metrics
accuracy = accuracy_score(true_labels, predicted_labels)
precision = precision_score(true_labels, predicted_labels)
recall = recall_score(true_labels, predicted_labels)
f1 = f1_score(true_labels, predicted_labels)

print(f"Accuracy: {accuracy:.4f}")
print(f"Precision: {precision:.4f}")
print(f"Recall: {recall:.4f}")
print(f"F1-score: {f1:.4f}")
# Out:
# Accuracy: 0.8189
# Precision: 0.7776
# Recall: 0.9949
# F1-score: 0.8729

# %%
from sklearn.metrics import confusion_matrix

# Compute confusion matrix
cm = confusion_matrix(true_labels, predicted_labels)

# Create a figure and a subplot
plt.figure(figsize=(8, 6))
plt.imshow(cm, interpolation='nearest', cmap=plt.cm.Blues)
plt.title('Confusion Matrix')
plt.colorbar()

# Setting the ticks for the classes
classes = [0, 1]
tick_marks = np.arange(len(classes))
plt.xticks(tick_marks, classes)
plt.yticks(tick_marks, classes)

# Adding annotations
thresh = cm.max() / 2.
for i in range(cm.shape[0]):
    for j in range(cm.shape[1]):
        plt.text(j, i, format(cm[i, j], 'd'),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

# Labeling axes
plt.xlabel('Predicted labels')
plt.ylabel('True labels')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Comparison

# %% [markdown]
# Kmeans and GMM algorithm do not rely on labeled data but rather seek feature similarity. This presents both opportunities and challenges. On one hand, CNNs rely heavily on the quality and quantity of data, they're complex models with many parameters, while Kmeans is relatively simple and faster. On the other hand, CNNs typically provide higher accuracy and performance due to their ability to capture higher-level features.
# GMMs can be computationally intensive for high-dimensional data. Estimating parameters for a large number of Gaussian components or high-dimensional data can be challenging and computationally expensive. Also GMMs may struggle with capturing high-dimensional data distributions and may not generalize well to unseen data.
#
# Also, while both CNNs and Kmeans have distinct purposes, they can complement each other in some scenarios. For example, one could use Kmeans for initial feature extraction or dimensionality reduction and then apply a classifier like a CNN for detailed analysis or classification. However, for image classification tasks, CNNs are typically more effective and widely adopted due to their ability to capture spatial features.
